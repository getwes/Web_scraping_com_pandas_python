# %%
#casso tenha erro no cmd ou no anacondas da um pip install e a biblioteca
import pandas as pd
import requests # pedindo solicitação para uma pagina web

# %%
header = {'user-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/111.0.0.0 Safari/537.36'}

# %%
url = 'https://br.tradingview.com/markets/stocks-brazil/market-movers-active/'
request = requests.get(url, headers=header)

df = pd.read_html(request.text)

df
# Out:
# [                      Cotação Volume 1D       Preço Variação % 1D Variação 1D  \
#  0   MGLU3MAGAZINE LUIZA ON NM  118.058M    3.23 BRL         3.86%    0.12 BRL
#  1         COGN3COGNA ON ON NM  100.076M    1.85 BRL        −8.87%   −0.18 BRL
#  2          HAPV3HAPVIDA ON NM    93.99M    2.25 BRL         8.70%    0.18 BRL
#  3              VIIA3VIA ON NM   54.155M    1.87 BRL         1.08%    0.02 BRL
#  4       AMER3AMERICANAS ON NM   46.413M    1.02 BRL         0.00%    0.00 BRL
#  ..                        ...       ...         ...           ...         ...
#  95        VIVT3TELEF BRASILON    2.021M   39.13 BRL         1.56%    0.60 BRL
#  96     SMTO3SAO MARTINHOON NM    1.892M   24.05 BRL         1.31%    0.31 BRL
#  97      DIRR3DIRECIONAL ON NM    1.741M   15.91 BRL         3.65%    0.56 BRL
#  98         AMBP3AMBIPAR ON NM    1.643M   18.08 BRL         1.69%    0.30 BRL
#  99       INTB3INTELBRAS ON NM    1.624M  25.440 BRL         2.33%   0.580 BRL
#
# ...

# %%
for i , tabela in enumerate(df):
    print('________________')
    print(i)
    print(tabela)
# Out:
# ________________
# 0
#                       Cotação Volume 1D       Preço Variação % 1D Variação 1D  \
# 0   MGLU3MAGAZINE LUIZA ON NM  118.058M    3.23 BRL         3.86%    0.12 BRL
# 1         COGN3COGNA ON ON NM  100.076M    1.85 BRL        −8.87%   −0.18 BRL
# 2          HAPV3HAPVIDA ON NM    93.99M    2.25 BRL         8.70%    0.18 BRL
# 3              VIIA3VIA ON NM   54.155M    1.87 BRL         1.08%    0.02 BRL
# 4       AMER3AMERICANAS ON NM   46.413M    1.02 BRL         0.00%    0.00 BRL
# ..                        ...       ...         ...           ...         ...
# 95        VIVT3TELEF BRASILON    2.021M   39.13 BRL         1.56%    0.60 BRL
# 96     SMTO3SAO MARTINHOON NM    1.892M   24.05 BRL         1.31%    0.31 BRL
# 97      DIRR3DIRECIONAL ON NM    1.741M   15.91 BRL         3.65%    0.56 BRL
# 98         AMBP3AMBIPAR ON NM    1.643M   18.08 BRL         1.69%    0.30 BRL
# 99       INTB3INTELBRAS ON NM    1.624M  25.440 BRL         2.33%   0.580 BRL
#
# ...

# %%
df = pd.DataFrame(df[0])

# %%
df
# Out:
#                       Cotação Volume 1D       Preço Variação % 1D Variação 1D  \
# 0   MGLU3MAGAZINE LUIZA ON NM  118.058M    3.23 BRL         3.86%    0.12 BRL
# 1         COGN3COGNA ON ON NM  100.076M    1.85 BRL        −8.87%   −0.18 BRL
# 2          HAPV3HAPVIDA ON NM    93.99M    2.25 BRL         8.70%    0.18 BRL
# 3              VIIA3VIA ON NM   54.155M    1.87 BRL         1.08%    0.02 BRL
# 4       AMER3AMERICANAS ON NM   46.413M    1.02 BRL         0.00%    0.00 BRL
# ..                        ...       ...         ...           ...         ...
# 95        VIVT3TELEF BRASILON    2.021M   39.13 BRL         1.56%    0.60 BRL
# 96     SMTO3SAO MARTINHOON NM    1.892M   24.05 BRL         1.31%    0.31 BRL
# 97      DIRR3DIRECIONAL ON NM    1.741M   15.91 BRL         3.65%    0.56 BRL
# 98         AMBP3AMBIPAR ON NM    1.643M   18.08 BRL         1.69%    0.30 BRL
# 99       INTB3INTELBRAS ON NM    1.624M  25.440 BRL         2.33%   0.580 BRL
#
# ...
